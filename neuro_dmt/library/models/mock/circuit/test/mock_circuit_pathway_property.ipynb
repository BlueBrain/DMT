# %%
import os
os.environ["LOGLEVEL"] = "PROD"

import numpy as np
import pandas as pd
from neuro_dmt.models.bluebrain.circuit.model import BlueBrainCircuitModel
from neuro_dmt.models.bluebrain.circuit.mock.test.mock_circuit_light\
    import circuit_composition, circuit_connectivity
from neuro_dmt.models.bluebrain.circuit.mock.circuit import\
    MockCircuit
# Out:
# ('region', 'layer', 'depth', 'height', 'mesocolumn', 'hypercolumn', 'mtype', 'etype', 'synapse_class', 'postsynaptic', 'presynaptic')
# ('region', 'layer', 'depth', 'height', 'mesocolumn', 'hypercolumn', 'mtype', 'etype', 'synapse_class', 'postsynaptic', 'presynaptic')
# ('region', 'layer', 'depth', 'height', 'mesocolumn', 'hypercolumn', 'mtype', 'etype', 'synapse_class', 'postsynaptic', 'presynaptic')
# ('region', 'layer', 'depth', 'height', 'mtype', 'etype', 'synapse_class')
# ('region', 'layer', 'depth', 'height', 'mtype', 'etype', 'synapse_class')

# %% [markdown]
# A few tests for `class CellType`.

# %% [markdown]
# We can define a `BlueBrainCircuitModel` instance for `MockCircuit`:

# %%
mock_circuit =\
    MockCircuit.build(
        circuit_composition,
        circuit_connectivity)
circuit_model =\
    BlueBrainCircuitModel(
        mock_circuit,
        label="BlueBrainCircuitModelMock")
conn_prob = circuit_model.connection_probability

# %%
pre_synaptic_cells = circuit_model.cells.sample(n=100)
post_synaptic_cells = circuit_model.cells.sample(n=100)
conn_prob.get_summary(
    pre_synaptic_cell_group=pre_synaptic_cells,
    post_synaptic_cell_group=post_synaptic_cells)
# Out:
# pairs_total               10000.0000
# pairs_connected             209.0000
# connection_probability        0.0209
# dtype: float64

# %%
pre_type = pd.Series({"mtype": "L23_MC"})
post_type = pd.Series({"mtype": "L23_MC"})
pathway = pd.Series({
    "pre_synaptic_mtype": "L23_MC",
    "post_synaptic_mtype": "L23_MC"})
result_series = conn_prob.get_summary(
    pre_synaptic_cell_group=pre_type,
    post_synaptic_cell_group=post_type, 
    number=100)
result_series
# Out:
# pairs_total               10000.000
# pairs_connected             180.000
# connection_probability        0.018
# dtype: float64

# %%
conn_prob.get_summary(
    pre_synaptic_cell_group=pre_type,
    post_synaptic_cell_group=post_type, 
    number=100,
    resample=True)
# Out:
# pairs_total               10000.0000
# pairs_connected             187.0000
# connection_probability        0.0187
# dtype: float64

# %%
from neuro_dmt.models.bluebrain.circuit.model.pathway import GroupByVariables
result_groupby = conn_prob(
    groupby=GroupByVariables(
        frozenset(["mtype"]),
        frozenset(["mtype"])))

# %%
result_groupby.head()
# Out:
#                                         pairs_total  pairs_connected  \
# pre_synaptic_mtype post_synaptic_mtype
# L23_ChC            L1_DAC                         2              0.0
#                    L23_ChC                        2              1.0
#                    L23_MC                         2              0.0
#                    L23_SBC                        4              0.0
#                    L4_LBC                         6              1.0
#
#                                         connection_probability
# pre_synaptic_mtype post_synaptic_mtype
# L23_ChC            L1_DAC                             0.000000
#                    L23_ChC                            0.500000
#                    L23_MC                             0.000000
#                    L23_SBC                            0.000000
#                    L4_LBC                             0.166667

# %%
from neuro_dmt.models.bluebrain.circuit.model.pathway import GroupByVariables
result_dataframes = conn_prob(
    pre_synaptic_cell_group=pre_synaptic_cells,
    post_synaptic_cell_group=post_synaptic_cells,
    groupby=GroupByVariables(("mtype", ), ("mtype", )),
    number=100,
    resample=True)
result_dataframes
# Out:
#                                         pairs_total  pairs_connected  \
# pre_synaptic_mtype post_synaptic_mtype
# L23_MC             L1_SLAC                        1              0.0
#                    L23_ChC                        2              0.0
#                    L23_MC                         1              0.0
#                    L4_NGC                         1              0.0
#                    L4_TPC                        14              0.0
#                    L5_MC                          3              0.0
#                    L5_TPC:A                       9              1.0
#                    L5_TPC:B                       7              0.0
#                    L5_UPC                         9              0.0
#                    L6_ChC                         5              0.0
#                    L6_IPC                        12              1.0
#                    L6_TPC:A                      11              1.0
#                    L6_TPC:B                      11              1.0
#                    L6_UPC                        14              0.0
# L4_LBC             L1_SLAC                        1              0.0
#                    L23_ChC                        2              0.0
#                    L23_MC                         1              0.0
#                    L4_NGC                         1              0.0
#                    L4_TPC                        14              0.0
#                    L5_MC                          3              0.0
#                    L5_TPC:A                       9              0.0
#                    L5_TPC:B                       7              0.0
#                    L5_UPC                         9              0.0
#                    L6_ChC                         5              0.0
#                    L6_IPC                        12              0.0
#                    L6_TPC:A                      11              0.0
#                    L6_TPC:B                      11              0.0
#                    L6_UPC                        14              2.0
# L4_TPC             L1_SLAC                       20              0.0
#                    L23_ChC                       40              0.0
# ...                                             ...              ...
# L6_TPC:A           L6_TPC:B                     132              1.0
#                    L6_UPC                       168              5.0
# L6_TPC:B           L1_SLAC                       10              0.0
#                    L23_ChC                       20              0.0
#                    L23_MC                        10              1.0
#                    L4_NGC                        10              1.0
#                    L4_TPC                       140              6.0
#                    L5_MC                         30              0.0
#                    L5_TPC:A                      90              1.0
#                    L5_TPC:B                      70              2.0
#                    L5_UPC                        90              3.0
#                    L6_ChC                        50              2.0
#                    L6_IPC                       120              3.0
#                    L6_TPC:A                     110              3.0
#                    L6_TPC:B                     110              6.0
#                    L6_UPC                       140              2.0
# L6_UPC             L1_SLAC                       12              0.0
#                    L23_ChC                       24              0.0
#                    L23_MC                        12              1.0
#                    L4_NGC                        12              0.0
#                    L4_TPC                       168              2.0
#                    L5_MC                         36              0.0
#                    L5_TPC:A                     108              1.0
#                    L5_TPC:B                      84              1.0
#                    L5_UPC                       108              2.0
#                    L6_ChC                        60              3.0
#                    L6_IPC                       144              5.0
#                    L6_TPC:A                     132              2.0
#                    L6_TPC:B                     132              1.0
#                    L6_UPC                       168              2.0
#
#                                         connection_probability
# pre_synaptic_mtype post_synaptic_mtype
# L23_MC             L1_SLAC                            0.000000
#                    L23_ChC                            0.000000
#                    L23_MC                             0.000000
#                    L4_NGC                             0.000000
#                    L4_TPC                             0.000000
#                    L5_MC                              0.000000
#                    L5_TPC:A                           0.111111
#                    L5_TPC:B                           0.000000
#                    L5_UPC                             0.000000
#                    L6_ChC                             0.000000
#                    L6_IPC                             0.083333
#                    L6_TPC:A                           0.090909
#                    L6_TPC:B                           0.090909
#                    L6_UPC                             0.000000
# L4_LBC             L1_SLAC                            0.000000
#                    L23_ChC                            0.000000
#                    L23_MC                             0.000000
#                    L4_NGC                             0.000000
#                    L4_TPC                             0.000000
#                    L5_MC                              0.000000
#                    L5_TPC:A                           0.000000
#                    L5_TPC:B                           0.000000
#                    L5_UPC                             0.000000
#                    L6_ChC                             0.000000
#                    L6_IPC                             0.000000
#                    L6_TPC:A                           0.000000
#                    L6_TPC:B                           0.000000
#                    L6_UPC                             0.142857
# L4_TPC             L1_SLAC                            0.000000
#                    L23_ChC                            0.000000
# ...                                                        ...
# L6_TPC:A           L6_TPC:B                           0.007576
#                    L6_UPC                             0.029762
# L6_TPC:B           L1_SLAC                            0.000000
#                    L23_ChC                            0.000000
#                    L23_MC                             0.100000
#                    L4_NGC                             0.100000
#                    L4_TPC                             0.042857
#                    L5_MC                              0.000000
#                    L5_TPC:A                           0.011111
#                    L5_TPC:B                           0.028571
#                    L5_UPC                             0.033333
#                    L6_ChC                             0.040000
#                    L6_IPC                             0.025000
#                    L6_TPC:A                           0.027273
#                    L6_TPC:B                           0.054545
#                    L6_UPC                             0.014286
# L6_UPC             L1_SLAC                            0.000000
#                    L23_ChC                            0.000000
#                    L23_MC                             0.083333
#                    L4_NGC                             0.000000
#                    L4_TPC                             0.011905
#                    L5_MC                              0.000000
#                    L5_TPC:A                           0.009259
#                    L5_TPC:B                           0.011905
#                    L5_UPC                             0.018519
#                    L6_ChC                             0.050000
#                    L6_IPC                             0.034722
#                    L6_TPC:A                           0.015152
#                    L6_TPC:B                           0.007576
#                    L6_UPC                             0.011905
#
# [182 rows x 3 columns]

# %%
result_dataframes = conn_prob.get_summary(
    pre_synaptic_cell_group=pre_synaptic_cells,
    post_synaptic_cell_group=post_synaptic_cells,
#    groupby=GroupByVariables(("mtype", ), ("mtype", )),
    number=100,
    resample=True)
result_dataframes
# Out:
# pairs_total               10000.0000
# pairs_connected             222.0000
# connection_probability        0.0222
# dtype: float64

# %%
result_no_cell_groups = conn_prob(
    groupby=GroupByVariables(("mtype", ), ("mtype", )),
    resample=True,
    number=100)
# Out:
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	334
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             Call to connection probability.
#             pathway:
#             	None
#             pre_synaptic_cell_group:
#             	None
#             post_synaptic_cell_group:
#             	None
#             to be group by:
#             	GroupByVariables(pre_synaptic_cell_type_specifier=('mtype',), post_synaptic_cell_type_specifier=('mtype',))
#             methodology:
#             	random
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	413
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             After processing arguments,
#             compute pathway property for:
#             pre_synaptic_cell_group: None
#             post_synaptic_cell_group: None
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	124
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             resolve cell group None
#             given that {'sampling_methodology': 'random', 'resample': True, 'number': 100}
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	124
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             resolve cell group              etype  layer  morph_class   mtype      nucleus region  \
# 0      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 1      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 2      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 3      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 4      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 5      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 6      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 7      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 8      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 9      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 10     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 11     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 12     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 13     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 14     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 15     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 16     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 17     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 18     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 19     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 20     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 21     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 22     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 23     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 24     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 25     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 26     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 27     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 28     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 29     not-defined      1  not-defined  L1_DAC  not-defined  brain
# ...            ...    ...          ...     ...          ...    ...
# 10258  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10259  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10260  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10261  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10262  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10263  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10264  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10265  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10266  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10267  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10268  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10269  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10270  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10271  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10272  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10273  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10274  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10275  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10276  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10277  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10278  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10279  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10280  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10281  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10282  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10283  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10284  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10285  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10286  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10287  not-defined      6  not-defined  L6_UPC  not-defined  brain
#
#       synapse_class           x            y           z    gid
# 0               INH   41.052264  1758.327285  192.429458      0
# 1               INH  208.606456  1809.153297  248.866335      1
# 2               INH  223.123319  1744.533738    7.341467      2
# 3               INH  154.624180  1813.856769  115.562979      3
# 4               INH  127.793366  1765.237579  171.089610      4
# 5               INH  243.701487  1780.451802   15.959767      5
# 6               INH   33.820639  1745.731652   97.807906      6
# 7               INH  228.081735  1829.672370   47.059948      7
# 8               INH  185.088429  1835.110051  227.862050      8
# 9               INH  110.190641  1747.458415  218.857998      9
# 10              INH   29.245852  1787.545252   56.648277     10
# 11              INH   26.831810  1818.734526   37.789123     11
# 12              INH  217.465842  1814.852700   68.761384     12
# 13              INH   31.214265  1790.929197  200.326074     13
# 14              INH  211.360856  1790.079196   10.219107     14
# 15              INH  224.304020  1745.627433    5.787763     15
# 16              INH   91.094260  1778.956530   47.830460     16
# 17              INH  109.367165  1763.508391   91.886957     17
# 18              INH   26.847163  1826.390321   83.515387     18
# 19              INH    3.335131  1735.453897   13.085606     19
# 20              INH   62.476338  1722.934312  202.108119     20
# 21              INH  208.284034  1780.534918   76.454493     21
# 22              INH   24.915338  1764.058973  221.824832     22
# 23              INH    2.426110  1839.359189   79.863049     23
# 24              INH   61.036852  1819.022168   62.419940     24
# 25              INH  225.482915  1757.463955  117.806574     25
# 26              INH  179.268520  1773.472699  176.239168     26
# 27              INH  179.096189  1739.455446   59.532855     27
# 28              INH  225.198656  1748.872457  247.361364     28
# 29              INH    6.233512  1798.046161  183.883035     29
# ...             ...         ...          ...         ...    ...
# 10258           EXC   96.244907    45.084554  140.903544  10258
# 10259           EXC  161.354263   184.832868   36.123860  10259
# 10260           EXC   19.552722   101.483199  241.857152  10260
# 10261           EXC   58.525195   596.620592  144.613624  10261
# 10262           EXC   75.440295    29.188669   97.903636  10262
# 10263           EXC  243.525773   385.587784   84.809515  10263
# 10264           EXC   19.076686   223.761627  123.361864  10264
# 10265           EXC  243.419888   587.894914   12.157094  10265
# 10266           EXC  102.024022   358.423698  227.612391  10266
# 10267           EXC   55.670786   344.279682   52.841430  10267
# 10268           EXC  119.359192   221.946238   48.759824  10268
# 10269           EXC  101.921328   294.782286   60.264987  10269
# 10270           EXC   18.099630     4.857070  108.588367  10270
# 10271           EXC  194.611529   324.025935  197.811090  10271
# 10272           EXC  249.658108    54.578288  221.893061  10272
# 10273           EXC   40.867999   164.057496  173.234815  10273
# 10274           EXC  232.843008   118.492374   30.895591  10274
# 10275           EXC  197.633318   358.976725   49.634203  10275
# 10276           EXC   25.572902   236.173217  168.698608  10276
# 10277           EXC  215.628625   393.125703  157.156260  10277
# 10278           EXC  204.738589   569.459681  146.026878  10278
# 10279           EXC  217.714374   443.480846  245.748476  10279
# 10280           EXC  191.228599   185.872116  128.885806  10280
# 10281           EXC  249.054108   336.392199  118.077076  10281
# 10282           EXC  147.168084   107.680295  134.443529  10282
# 10283           EXC   82.838817   371.145907   67.252269  10283
# 10284           EXC  196.444243   369.519173  185.458116  10284
# 10285           EXC  124.492322   573.389705  174.766141  10285
# 10286           EXC  246.157056   278.933444  213.417273  10286
# 10287           EXC  145.222931   340.658008  213.176439  10287
#
# [10288 rows x 11 columns]
#             given that {'sampling_methodology': 'random', 'resample': True, 'number': 100}
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	157
# 	code_context: 	['                logger.get_source_info(),\n']
# 	index: 0
#
#
#                 Final result for cell group, dataframe with shape (100, 11)
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	124
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             resolve cell group None
#             given that {'sampling_methodology': 'random', 'resample': True, 'number': 100}
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	124
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             resolve cell group              etype  layer  morph_class   mtype      nucleus region  \
# 0      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 1      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 2      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 3      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 4      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 5      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 6      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 7      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 8      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 9      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 10     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 11     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 12     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 13     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 14     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 15     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 16     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 17     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 18     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 19     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 20     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 21     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 22     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 23     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 24     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 25     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 26     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 27     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 28     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 29     not-defined      1  not-defined  L1_DAC  not-defined  brain
# ...            ...    ...          ...     ...          ...    ...
# 10258  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10259  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10260  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10261  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10262  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10263  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10264  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10265  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10266  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10267  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10268  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10269  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10270  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10271  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10272  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10273  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10274  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10275  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10276  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10277  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10278  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10279  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10280  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10281  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10282  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10283  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10284  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10285  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10286  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10287  not-defined      6  not-defined  L6_UPC  not-defined  brain
#
#       synapse_class           x            y           z    gid
# 0               INH   41.052264  1758.327285  192.429458      0
# 1               INH  208.606456  1809.153297  248.866335      1
# 2               INH  223.123319  1744.533738    7.341467      2
# 3               INH  154.624180  1813.856769  115.562979      3
# 4               INH  127.793366  1765.237579  171.089610      4
# 5               INH  243.701487  1780.451802   15.959767      5
# 6               INH   33.820639  1745.731652   97.807906      6
# 7               INH  228.081735  1829.672370   47.059948      7
# 8               INH  185.088429  1835.110051  227.862050      8
# 9               INH  110.190641  1747.458415  218.857998      9
# 10              INH   29.245852  1787.545252   56.648277     10
# 11              INH   26.831810  1818.734526   37.789123     11
# 12              INH  217.465842  1814.852700   68.761384     12
# 13              INH   31.214265  1790.929197  200.326074     13
# 14              INH  211.360856  1790.079196   10.219107     14
# 15              INH  224.304020  1745.627433    5.787763     15
# 16              INH   91.094260  1778.956530   47.830460     16
# 17              INH  109.367165  1763.508391   91.886957     17
# 18              INH   26.847163  1826.390321   83.515387     18
# 19              INH    3.335131  1735.453897   13.085606     19
# 20              INH   62.476338  1722.934312  202.108119     20
# 21              INH  208.284034  1780.534918   76.454493     21
# 22              INH   24.915338  1764.058973  221.824832     22
# 23              INH    2.426110  1839.359189   79.863049     23
# 24              INH   61.036852  1819.022168   62.419940     24
# 25              INH  225.482915  1757.463955  117.806574     25
# 26              INH  179.268520  1773.472699  176.239168     26
# 27              INH  179.096189  1739.455446   59.532855     27
# 28              INH  225.198656  1748.872457  247.361364     28
# 29              INH    6.233512  1798.046161  183.883035     29
# ...             ...         ...          ...         ...    ...
# 10258           EXC   96.244907    45.084554  140.903544  10258
# 10259           EXC  161.354263   184.832868   36.123860  10259
# 10260           EXC   19.552722   101.483199  241.857152  10260
# 10261           EXC   58.525195   596.620592  144.613624  10261
# 10262           EXC   75.440295    29.188669   97.903636  10262
# 10263           EXC  243.525773   385.587784   84.809515  10263
# 10264           EXC   19.076686   223.761627  123.361864  10264
# 10265           EXC  243.419888   587.894914   12.157094  10265
# 10266           EXC  102.024022   358.423698  227.612391  10266
# 10267           EXC   55.670786   344.279682   52.841430  10267
# 10268           EXC  119.359192   221.946238   48.759824  10268
# 10269           EXC  101.921328   294.782286   60.264987  10269
# 10270           EXC   18.099630     4.857070  108.588367  10270
# 10271           EXC  194.611529   324.025935  197.811090  10271
# 10272           EXC  249.658108    54.578288  221.893061  10272
# 10273           EXC   40.867999   164.057496  173.234815  10273
# 10274           EXC  232.843008   118.492374   30.895591  10274
# 10275           EXC  197.633318   358.976725   49.634203  10275
# 10276           EXC   25.572902   236.173217  168.698608  10276
# 10277           EXC  215.628625   393.125703  157.156260  10277
# 10278           EXC  204.738589   569.459681  146.026878  10278
# 10279           EXC  217.714374   443.480846  245.748476  10279
# 10280           EXC  191.228599   185.872116  128.885806  10280
# 10281           EXC  249.054108   336.392199  118.077076  10281
# 10282           EXC  147.168084   107.680295  134.443529  10282
# 10283           EXC   82.838817   371.145907   67.252269  10283
# 10284           EXC  196.444243   369.519173  185.458116  10284
# 10285           EXC  124.492322   573.389705  174.766141  10285
# 10286           EXC  246.157056   278.933444  213.417273  10286
# 10287           EXC  145.222931   340.658008  213.176439  10287
#
# [10288 rows x 11 columns]
#             given that {'sampling_methodology': 'random', 'resample': True, 'number': 100}
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	157
# 	code_context: 	['                logger.get_source_info(),\n']
# 	index: 0
#
#
#                 Final result for cell group, dataframe with shape (100, 11)
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	223
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             cache result for specifiers:
#             	pre_synaptic: frozenset({'mtype'})
#             	post_synaptic: frozenset({'mtype'})
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	497
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             Get connection probability for
#             100 pre synaptic cells
#             100 post synaptic cells
#
# ================================================================================

# %%
print(result_no_cell_groups.sum())
result_no_cell_groups.head()
# Out:
# pairs                   total        10000.000000
#                         connected      201.000000
# connection_probability                   5.106456
# dtype: float64
#                                        pairs           connection_probability
#                                        total connected
# pre_synaptic_mtype post_synaptic_mtype
# L1_SLAC            L1_DAC                  1       0.0                    0.0
#                    L1_SLAC                 1       0.0                    0.0
#                    L23_ChC                 1       0.0                    0.0
#                    L23_MC                  2       0.0                    0.0
#                    L23_SBC                 2       0.0                    0.0

# %%
pre_synaptic = pd.Series({"mtype": "L6_UPC"})
post_synaptic = pd.Series({"mtype": "L6_UPC"})
pathway = CellType.pathway(pre_synaptic, post_synaptic)
result_no_cell_groups.head()
# Out:
#                                        pairs           connection_probability
#                                        total connected
# pre_synaptic_mtype post_synaptic_mtype
# L1_SLAC            L1_DAC                  1       0.0                    0.0
#                    L1_SLAC                 1       0.0                    0.0
#                    L23_ChC                 1       0.0                    0.0
#                    L23_MC                  2       0.0                    0.0
#                    L23_SBC                 2       0.0                    0.0

# %%
levels_and_values = [
    ('_'.join(k), v) for k, v in zip(pathway.index.values, pathway.values)]
levels = tuple('_'.join(k) for k in pathway.index.values)
values = pathway.values

result_no_cell_groups.xs(
    values,
    level=levels)
# Out:
#                                        pairs           connection_probability
#                                        total connected
# pre_synaptic_mtype post_synaptic_mtype
# L6_UPC             L6_UPC                150       2.0               0.013333

# %%
result_no_cell_groups_no_types = conn_prob(number=1000)
# Out:
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	334
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             Call to connection probability.
#             pathway:
#             	None
#             pre_synaptic_cell_group:
#             	None
#             post_synaptic_cell_group:
#             	None
#             to be group by:
#             	GroupByVariables(pre_synaptic_cell_type_specifier=None, post_synaptic_cell_type_specifier=None)
#             methodology:
#             	random
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	413
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             After processing arguments,
#             compute pathway property for:
#             pre_synaptic_cell_group: None
#             post_synaptic_cell_group: None
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	124
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             resolve cell group None
#             given that {'sampling_methodology': 'random', 'resample': False, 'number': 1000}
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	124
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             resolve cell group              etype  layer  morph_class   mtype      nucleus region  \
# 0      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 1      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 2      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 3      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 4      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 5      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 6      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 7      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 8      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 9      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 10     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 11     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 12     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 13     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 14     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 15     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 16     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 17     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 18     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 19     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 20     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 21     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 22     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 23     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 24     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 25     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 26     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 27     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 28     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 29     not-defined      1  not-defined  L1_DAC  not-defined  brain
# ...            ...    ...          ...     ...          ...    ...
# 10258  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10259  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10260  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10261  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10262  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10263  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10264  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10265  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10266  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10267  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10268  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10269  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10270  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10271  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10272  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10273  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10274  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10275  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10276  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10277  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10278  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10279  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10280  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10281  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10282  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10283  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10284  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10285  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10286  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10287  not-defined      6  not-defined  L6_UPC  not-defined  brain
#
#       synapse_class           x            y           z    gid
# 0               INH   41.052264  1758.327285  192.429458      0
# 1               INH  208.606456  1809.153297  248.866335      1
# 2               INH  223.123319  1744.533738    7.341467      2
# 3               INH  154.624180  1813.856769  115.562979      3
# 4               INH  127.793366  1765.237579  171.089610      4
# 5               INH  243.701487  1780.451802   15.959767      5
# 6               INH   33.820639  1745.731652   97.807906      6
# 7               INH  228.081735  1829.672370   47.059948      7
# 8               INH  185.088429  1835.110051  227.862050      8
# 9               INH  110.190641  1747.458415  218.857998      9
# 10              INH   29.245852  1787.545252   56.648277     10
# 11              INH   26.831810  1818.734526   37.789123     11
# 12              INH  217.465842  1814.852700   68.761384     12
# 13              INH   31.214265  1790.929197  200.326074     13
# 14              INH  211.360856  1790.079196   10.219107     14
# 15              INH  224.304020  1745.627433    5.787763     15
# 16              INH   91.094260  1778.956530   47.830460     16
# 17              INH  109.367165  1763.508391   91.886957     17
# 18              INH   26.847163  1826.390321   83.515387     18
# 19              INH    3.335131  1735.453897   13.085606     19
# 20              INH   62.476338  1722.934312  202.108119     20
# 21              INH  208.284034  1780.534918   76.454493     21
# 22              INH   24.915338  1764.058973  221.824832     22
# 23              INH    2.426110  1839.359189   79.863049     23
# 24              INH   61.036852  1819.022168   62.419940     24
# 25              INH  225.482915  1757.463955  117.806574     25
# 26              INH  179.268520  1773.472699  176.239168     26
# 27              INH  179.096189  1739.455446   59.532855     27
# 28              INH  225.198656  1748.872457  247.361364     28
# 29              INH    6.233512  1798.046161  183.883035     29
# ...             ...         ...          ...         ...    ...
# 10258           EXC   96.244907    45.084554  140.903544  10258
# 10259           EXC  161.354263   184.832868   36.123860  10259
# 10260           EXC   19.552722   101.483199  241.857152  10260
# 10261           EXC   58.525195   596.620592  144.613624  10261
# 10262           EXC   75.440295    29.188669   97.903636  10262
# 10263           EXC  243.525773   385.587784   84.809515  10263
# 10264           EXC   19.076686   223.761627  123.361864  10264
# 10265           EXC  243.419888   587.894914   12.157094  10265
# 10266           EXC  102.024022   358.423698  227.612391  10266
# 10267           EXC   55.670786   344.279682   52.841430  10267
# 10268           EXC  119.359192   221.946238   48.759824  10268
# 10269           EXC  101.921328   294.782286   60.264987  10269
# 10270           EXC   18.099630     4.857070  108.588367  10270
# 10271           EXC  194.611529   324.025935  197.811090  10271
# 10272           EXC  249.658108    54.578288  221.893061  10272
# 10273           EXC   40.867999   164.057496  173.234815  10273
# 10274           EXC  232.843008   118.492374   30.895591  10274
# 10275           EXC  197.633318   358.976725   49.634203  10275
# 10276           EXC   25.572902   236.173217  168.698608  10276
# 10277           EXC  215.628625   393.125703  157.156260  10277
# 10278           EXC  204.738589   569.459681  146.026878  10278
# 10279           EXC  217.714374   443.480846  245.748476  10279
# 10280           EXC  191.228599   185.872116  128.885806  10280
# 10281           EXC  249.054108   336.392199  118.077076  10281
# 10282           EXC  147.168084   107.680295  134.443529  10282
# 10283           EXC   82.838817   371.145907   67.252269  10283
# 10284           EXC  196.444243   369.519173  185.458116  10284
# 10285           EXC  124.492322   573.389705  174.766141  10285
# 10286           EXC  246.157056   278.933444  213.417273  10286
# 10287           EXC  145.222931   340.658008  213.176439  10287
#
# [10288 rows x 11 columns]
#             given that {'sampling_methodology': 'random', 'resample': False, 'number': 1000}
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	157
# 	code_context: 	['                logger.get_source_info(),\n']
# 	index: 0
#
#
#                 Final result for cell group, dataframe with shape (1000, 11)
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	124
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             resolve cell group None
#             given that {'sampling_methodology': 'random', 'resample': False, 'number': 1000}
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	124
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             resolve cell group              etype  layer  morph_class   mtype      nucleus region  \
# 0      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 1      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 2      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 3      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 4      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 5      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 6      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 7      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 8      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 9      not-defined      1  not-defined  L1_DAC  not-defined  brain
# 10     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 11     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 12     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 13     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 14     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 15     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 16     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 17     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 18     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 19     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 20     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 21     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 22     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 23     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 24     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 25     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 26     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 27     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 28     not-defined      1  not-defined  L1_DAC  not-defined  brain
# 29     not-defined      1  not-defined  L1_DAC  not-defined  brain
# ...            ...    ...          ...     ...          ...    ...
# 10258  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10259  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10260  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10261  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10262  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10263  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10264  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10265  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10266  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10267  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10268  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10269  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10270  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10271  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10272  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10273  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10274  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10275  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10276  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10277  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10278  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10279  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10280  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10281  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10282  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10283  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10284  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10285  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10286  not-defined      6  not-defined  L6_UPC  not-defined  brain
# 10287  not-defined      6  not-defined  L6_UPC  not-defined  brain
#
#       synapse_class           x            y           z    gid
# 0               INH   41.052264  1758.327285  192.429458      0
# 1               INH  208.606456  1809.153297  248.866335      1
# 2               INH  223.123319  1744.533738    7.341467      2
# 3               INH  154.624180  1813.856769  115.562979      3
# 4               INH  127.793366  1765.237579  171.089610      4
# 5               INH  243.701487  1780.451802   15.959767      5
# 6               INH   33.820639  1745.731652   97.807906      6
# 7               INH  228.081735  1829.672370   47.059948      7
# 8               INH  185.088429  1835.110051  227.862050      8
# 9               INH  110.190641  1747.458415  218.857998      9
# 10              INH   29.245852  1787.545252   56.648277     10
# 11              INH   26.831810  1818.734526   37.789123     11
# 12              INH  217.465842  1814.852700   68.761384     12
# 13              INH   31.214265  1790.929197  200.326074     13
# 14              INH  211.360856  1790.079196   10.219107     14
# 15              INH  224.304020  1745.627433    5.787763     15
# 16              INH   91.094260  1778.956530   47.830460     16
# 17              INH  109.367165  1763.508391   91.886957     17
# 18              INH   26.847163  1826.390321   83.515387     18
# 19              INH    3.335131  1735.453897   13.085606     19
# 20              INH   62.476338  1722.934312  202.108119     20
# 21              INH  208.284034  1780.534918   76.454493     21
# 22              INH   24.915338  1764.058973  221.824832     22
# 23              INH    2.426110  1839.359189   79.863049     23
# 24              INH   61.036852  1819.022168   62.419940     24
# 25              INH  225.482915  1757.463955  117.806574     25
# 26              INH  179.268520  1773.472699  176.239168     26
# 27              INH  179.096189  1739.455446   59.532855     27
# 28              INH  225.198656  1748.872457  247.361364     28
# 29              INH    6.233512  1798.046161  183.883035     29
# ...             ...         ...          ...         ...    ...
# 10258           EXC   96.244907    45.084554  140.903544  10258
# 10259           EXC  161.354263   184.832868   36.123860  10259
# 10260           EXC   19.552722   101.483199  241.857152  10260
# 10261           EXC   58.525195   596.620592  144.613624  10261
# 10262           EXC   75.440295    29.188669   97.903636  10262
# 10263           EXC  243.525773   385.587784   84.809515  10263
# 10264           EXC   19.076686   223.761627  123.361864  10264
# 10265           EXC  243.419888   587.894914   12.157094  10265
# 10266           EXC  102.024022   358.423698  227.612391  10266
# 10267           EXC   55.670786   344.279682   52.841430  10267
# 10268           EXC  119.359192   221.946238   48.759824  10268
# 10269           EXC  101.921328   294.782286   60.264987  10269
# 10270           EXC   18.099630     4.857070  108.588367  10270
# 10271           EXC  194.611529   324.025935  197.811090  10271
# 10272           EXC  249.658108    54.578288  221.893061  10272
# 10273           EXC   40.867999   164.057496  173.234815  10273
# 10274           EXC  232.843008   118.492374   30.895591  10274
# 10275           EXC  197.633318   358.976725   49.634203  10275
# 10276           EXC   25.572902   236.173217  168.698608  10276
# 10277           EXC  215.628625   393.125703  157.156260  10277
# 10278           EXC  204.738589   569.459681  146.026878  10278
# 10279           EXC  217.714374   443.480846  245.748476  10279
# 10280           EXC  191.228599   185.872116  128.885806  10280
# 10281           EXC  249.054108   336.392199  118.077076  10281
# 10282           EXC  147.168084   107.680295  134.443529  10282
# 10283           EXC   82.838817   371.145907   67.252269  10283
# 10284           EXC  196.444243   369.519173  185.458116  10284
# 10285           EXC  124.492322   573.389705  174.766141  10285
# 10286           EXC  246.157056   278.933444  213.417273  10286
# 10287           EXC  145.222931   340.658008  213.176439  10287
#
# [10288 rows x 11 columns]
#             given that {'sampling_methodology': 'random', 'resample': False, 'number': 1000}
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	157
# 	code_context: 	['                logger.get_source_info(),\n']
# 	index: 0
#
#
#                 Final result for cell group, dataframe with shape (1000, 11)
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	223
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             cache result for specifiers:
#             	pre_synaptic: None
#             	post_synaptic: None
#
# ================================================================================
#
# ================================================================================
# /home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py Logger
# FUNDA@<2019-11-06 21:28:19>
# Traceback:
# 	filename: 	/home/muchu/work/bbp/work/validations/dmt/v2/neuro_dmt/models/bluebrain/circuit/model/pathway.py
# 	lineno: 	497
# 	code_context: 	['            logger.get_source_info(),\n']
# 	index: 0
#
#
#             Get connection probability for
#             1000 pre synaptic cells
#             1000 post synaptic cells
#
# ================================================================================

# %%
result_no_cell_groups_no_types
# Out:
# total        1000000
# connected      19473
# dtype: int64

# %% [markdown]
# Test pathway properties in circuit analysis, using the mock circuit.

# %%
from neuro_dmt.models.bluebrain.circuit.adapter import BlueBrainCircuitAdapter
from neuro_dmt.models.bluebrain.circuit.test.test_connectome_analysis import *
phenomenon = Phenomenon(
    "Connection Probability",
    """
    Probability that two neurons in a pathway are connected.
    While mostly interested in `mtype->mtype` pathways, we can define
    a pathway as the group of connected neurons with pre-synaptic and
    post-synaptic neurons belonging to two parametrically defined groups.
    As an example consider neuron populations defined by not only `mtype`
    but also by soma-distance from a given location.
    """,
    group="Connectome")
pathways = mock_circuit_model.pathways(frozenset({"mtype", })).sample(n=5)
analysis = BrainCircuitAnalysis(
    phenomenon=phenomenon,
    AdapterInterface=ConnectionProbabilityInterface,
    measurement_parameters=Parameters(pathways),
        plotter=HeatMap(
        xvar=("pre_synaptic", "mtype"),
        xlabel="pre-mtype",
        yvar=("post_synaptic", "mtype"),
        ylabel="post-mtype",
        vvar=("connection_probability", "mean")))
analysis_test = BlueBrainCircuitAnalysisTest(
    analysis=analysis)
adapter = BlueBrainCircuitAdapter()
analysis_test.test_circuit_model(circuit_label)
measurement_values =\
    analysis.get_measurement(mock_circuit_model, adapter, sample_size=10)
# Out:
# ('region', 'layer', 'depth', 'height', 'mesocolumn', 'hypercolumn', 'mtype', 'etype', 'synapse_class', 'postsynaptic', 'presynaptic')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-f6963d14b44d> in <module>
#      26     analysis=analysis)
#      27 adapter = BlueBrainCircuitAdapter()
# ---> 28 analysis_test.test_circuit_model(circuit_label)
#      29 measurement_values =\
#      30     analysis.get_measurement(mock_circuit_model, adapter, sample_size=10)
#
# ~/.vmgr_repo/py37/lib/python3.7/site-packages/neuro_dmt/models/bluebrain/circuit/test/__init__.py in __getattribute__(self, name_attr)
#     106             raise AttributeError(
#     107                 "'{}' object has no attribute {}"\
# --> 108                 .format(__class__.__name__, name_attr))
#     109
#     110         circuit_analysis_method = getattr(
#
# AttributeError: 'BlueBrainCircuitAnalysisTest' object has no attribute test_circuit_model

# %%
analysis_test.test_circuit_data_path(mock_circuit_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-9620274aecf4> in <module>
# ----> 1 analysis_test.test_circuit_data_path(mock_circuit_model)
#
# ~/.vmgr_repo/py37/lib/python3.7/site-packages/neuro_dmt/models/bluebrain/circuit/test/__init__.py in test_circuit_data_path(self, circuit_model, *args, **kwargs)
#     123         `BlueBrainCircuitModel` should be able to load circuit data.
#     124         """
# --> 125         path = circuit_model.get_path("jinga")
#     126         dir = os.path.dirname(path)
#     127         assert dir == get_path_circuit(circuit_label).as_posix()
#
# ~/.vmgr_repo/py37/lib/python3.7/site-packages/neuro_dmt/models/bluebrain/circuit/model/__init__.py in get_path(self, *relative_path)
#     119         the circuit's location.
#     120         """
# --> 121         return os.path.join(self.path_circuit_data, *relative_path)
#     122
#     123     @lazyfield
#
# ~/.vmgr_repo/py37/lib/python3.7/site-packages/dmt/tk/field/field.py in __get__(self, instance, owner)
#     130             return getattr(
#     131                 instance,
# --> 132                 self._get_instance_attribute_name(instance))
#     133         #assuming owner is the class in which this Field was defined...
#     134         return self
#
# AttributeError: 'BlueBrainCircuitModel' object has no attribute '$object_path_circuit_data'

# %%
from dmt.data.observation import measurement
measurement.get_summary(measurement_values.loc["BlueBrainCircuitModelMockLight"])
# Out:
#                                              connection_probability            \
#                                                                size      mean
# (pre_synaptic, mtype) (post_synaptic, mtype)
# L1_DAC                L1_SLAC                                    10  0.019184
# L23_SBC               L23_ChC                                    10  0.017860
# L5_DBC                L4_NGC                                     10  0.018505
# L5_TPC:A              L6_IPC                                     10  0.019310
# L6_TPC:A              L4_TPC                                     10  0.018920
#
#
#                                                    std
# (pre_synaptic, mtype) (post_synaptic, mtype)
# L1_DAC                L1_SLAC                 0.000000
# L23_SBC               L23_ChC                 0.001097
# L5_DBC                L4_NGC                  0.001042
# L5_TPC:A              L6_IPC                  0.001284
# L6_TPC:A              L4_TPC                  0.001036

# %%
from neuro_dmt.models.bluebrain.circuit.model.pathway import GroupByVariables
result = conn_prob(
        pre_synaptic_cell_group=pre_synaptic_cells,
        post_synaptic_cell_group=post_synaptic_cells,
        groupby=GroupByVariables(
            pre_synaptic_cell_type_specifier={"mtype",},
            post_synaptic_cell_type_specifier={"mtype",}))
pre_synaptic_cells.shape, result.shape
# Out:
# group summary
# ((100, 11), (256, 3))

# %%
result = conn_prob(
        pre_synaptic_cell_group=pre_synaptic_cells,
        post_synaptic_cell_group=post_synaptic_cells)
result
# Out:
# 0.0203

# %%
from neuro_dmt.models.bluebrain.circuit.model.test.pathway import *
test_call_with_dataframes_and_groupby()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-933d70c66d82> in <module>
#       1 from neuro_dmt.models.bluebrain.circuit.model.test.pathway import *
# ----> 2 test_call_with_dataframes_and_groupby()
#
# ~/.vmgr_repo/py37/lib/python3.7/site-packages/neuro_dmt/models/bluebrain/circuit/model/test/pathway.py in test_call_with_dataframes_and_groupby()
#     237         groupby=GroupByVariables(
#     238             pre_synaptic_cell_type_specifier={"mtype",},
# --> 239             post_synaptic_cell_type_specifier={"mtype",}))
#     240
#     241     assert isinstance(result, pd.DataFrame)
#
# ~/.vmgr_repo/py37/lib/python3.7/site-packages/neuro_dmt/models/bluebrain/circuit/model/pathway.py in __call__(self, pathway, pre_synaptic_cell_group, post_synaptic_cell_group, groupby, by, given, resample, sampling_methodology, number, with_summary_statistics)
#     528                     measurement_pairs,
#     529                     groupby.pre_synaptic_cell_type_specifier,
# --> 530                     groupby.post_synaptic_cell_type_specifier)
#     531
#     532             summary = self._full_summary(measurement_pairs)
#
# ~/.vmgr_repo/py37/lib/python3.7/site-packages/neuro_dmt/models/bluebrain/circuit/model/pathway.py in _grouped_summary(self, measurement_pairs, pre_synaptic_cell_type_specifier, post_synaptic_cell_type_specifier)
#     314                 .rename(
#     315                     columns=self.columns)
# --> 316                 for pairs in measurement_pairs])\
#     317             .groupby(
#     318                 pre_synaptic_columns
#
# ~/.vmgr_repo/py37/lib/python3.7/site-packages/neuro_dmt/models/bluebrain/circuit/model/pathway.py in <listcomp>(.0)
#     314                 .rename(
#     315                     columns=self.columns)
# --> 316                 for pairs in measurement_pairs])\
#     317             .groupby(
#     318                 pre_synaptic_columns
#
# ~/.vmgr_repo/py37/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2979             if is_iterator(key):
#    2980                 key = list(key)
# -> 2981             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2982
#    2983         # take() does not accept boolean indexers
#
# ~/.vmgr_repo/py37/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1269                 # When setting, missing keys are not allowed, even with .loc:
#    1270                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1271                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1272         else:
#    1273             try:
#
# ~/.vmgr_repo/py37/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1076
#    1077         self._validate_read_indexer(
# -> 1078             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1079         )
#    1080         return keyarr, indexer
#
# ~/.vmgr_repo/py37/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1169             if not (self.name == "loc" and not raise_missing):
#    1170                 not_found = list(set(key) - set(ax))
# -> 1171                 raise KeyError("{} not in index".format(not_found))
#    1172
#    1173             # we skip the warning on Categorical/Interval
#
# KeyError: "['pre_synaptic_mtype', 'post_synaptic_mtype'] not in index"

# %% [markdown]
# ## Pathway property
#
# A `PathwayProperty` instance is a callable -- and callable:
# ```
# class PathwayProperty(WithFields):
#     """
#     Compute and store a circuit's pathway properties.
#     """
#     phenomenon = Field(
#         """
#         A label to go with the pathway property.
#         """)
#     circuit_model = Field(
#         """
#         The circuit model for which this `PathwayProperty` has been defined.
#         """)
#     max_length_cell_type_specification = Field(
#         """
#         Max length of the cell type specifier that can be stored.
#         """,
#         __default_value__=2)
#
#     def __call__(self,
#             pre_synaptic_cell_group,
#             post_synaptic_cell_group,
#             by=None,
#             given=None,
#             resample=False,
#             sampling_methodology=SamplingMethodology.random,
#             number=100):
#         """
#         Compute, or retrieve from the store...
#
#         Arguments
#         -------------
#         pre_synaptic_cell_group:  Array<GID>,
#         ~                         Mapping<CellProperty==>Value>,
#         ~                         pandas.Series<CellProperty>,
#         ~                         pandas.DataFrame<CellProperty>
#         post_synaptic_cell_group: Array<GID>,
#         ~                         Mapping<CellProperty==>Value>,
#         ~                         pandas.Series<CellProperty>,
#         ~                         pandas.DataFrame<CellProperty>
#         by : A property of a connection ((pre_synaptic_cell, post_synaptic_cell).
#              Pathway property will be computed for given values of this variable.
#              If a list of variables, the computation will be conditioned on all
#              the variables.
#         given: A dict providing variables and their values for which the
#                the pathway property will be returned.
#
#         Returns
#         ---------------
#         pd.Series if
#
#         """
# ```

# %%
s = circuit_model.connection_probability(
    np.array([1,2]),
    np.array([3,4]))

# %%
s

# %%
from neuro_dmt.models.bluebrain.circuit.model.pathway import SamplingMethodology
pre_cell_group = pd.Series({"mtype": "L23_MC"})
post_cell_group = pd.Series({"mtype": "L23_MC"})
s = circuit_model.connection_probability(
    pre_cell_group,
    post_cell_group,
    sampling_methodology=SamplingMethodology.exhaustive)

# %%
mock_circuit.cells.get({"mtype": "L23_ChC"}).head()

# %%
mock_circuit.cells.get(mock_circuit.connectome.afferent_gids(140)).head()

# %%
s.xs("L1_DAC", level="post_synaptic_mtype")

# %%
l1dacs = mock_circuit.cells.get({"mtype": "L1_DAC"}).index.values

# %%
l1dac_affs = np.concatenate(
    [mock_circuit.connectome.afferent_gids(post_gid)
     for post_gid in l1dacs],
    axis=0)

# %%
l1dac_aff_mtypes = mock_circuit.cells.get(l1dac_affs, ["mtype"])

# %%
l1dac_aff_mtypes.mtype.value_counts()

# %%
mock_circuit.cells.get().mtype.value_counts()

# %%
127890 / 70

# %%
circuit_model.get_connection_probability(
    pre_cell_group, post_cell_group)

# %%
def get_connection_probability(
            pre_cell_type_specifier,
            post_cell_type_specifier):
        """
        Compute connection probability once for either the entire
        circuit, or samples of afferent, or samples of  efferent,
        or samples of both efferent and afferent cells.
        """
        labels_pre_specifier =[
            "pre_synaptic_{}".format(c)
            for c in pre_cell_type_specifier]
        labels_post_specifier = [
            "post_synaptic_{}".format(c)
            for c in post_cell_type_specifier]
        cells = circuit_model.cells
        def _get_summary_connections(post_cell):
            return cells[
                list(pre_cell_type_specifier)
            ].rename(
                columns=lambda c: "pre_synaptic_{}".format(c)
            ).assign(
                number_pairs=np.in1d(
                    circuit_model.cells.index.values,
                    circuit_model.connectome.afferent_gids(post_cell.gid))
            ).groupby(
                labels_pre_specifier
            ).agg(
                ["size", "sum"]
            ).rename(
                columns={"size": "total", "sum": "connected"}
            ).assign(**{
                "post_synaptic_{}".format(p): post_cell[p] 
                for p in post_cell_type_specifier}
            ).reset_index(
            ).set_index(list(
                labels_pre_specifier + labels_post_specifier)
            )

        def _connection_probability(summary):
            """
            Compute connection probability between pairs
            """
            return summary.number_pairs.connected / summary.number_pairs.total

        return pd.concat(
            [_get_summary_connections(post_cell)
             for _, post_cell in cells.iterrows()]
        ).groupby(list(
            labels_pre_specifier + labels_post_specifier)
        ).agg(
            "sum"
        ).assign(
            connection_probability=_connection_probability )

# %%
#sdirect = get_connection_probability(("mtype", ), ("mtype", ))
#sdirect.xs("L1_DAC", level="post_synaptic_mtype")

# %%
l1dac_aff_mtypes.mtype.value_counts()
